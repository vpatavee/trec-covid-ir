# %%
import scispacy
import spacy

stopwords = {
    'a', 'about', 'above', 'according', 'across', 'after', 'afterwards', 'again', 
    'against', 'albeit', 'all', 'almost', 'alone', 'along', 'already', 'also', 
    'although', 'always', 'am', 'among', 'amongst', 'an', 'and', 'another', 
    'any', 'anybody', 'anyhow', 'anyone', 'anything', 'anyway', 'anywhere', 
    'apart', 'are', 'around', 'as', 'at', 'av', 'be', 'became', 'because', 
    'become', 'becomes', 'becoming', 'been', 'before', 'beforehand', 'behind', 
    'being', 'below', 'beside', 'besides', 'between', 'beyond', 'both', 'but', 
    'by', 'can', 'cannot', 'canst', 'certain', 'cf', 'choose', 'contrariwise', 
    'cos', 'could', 'cu', 'day', 'do', 'does', 'doesn', 't', 'doing', 'dost', 
    'doth', 'double', 'down', 'dual', 'during', 'each', 'either', 'else', 
    'elsewhere', 'enough', 'et', 'etc', 'even', 'ever', 'every', 'everybody', 
    'everyone', 'everything', 'everywhere', 'except', 'excepted', 'excepting', 
    'exception', 'exclude', 'excluding', 'exclusive', 'far', 'farther', 
    'farthest', 'few', 'ff', 'first', 'for', 'formerly', 'forth', 'forward', 
    'from', 'front', 'further', 'furthermore', 'furthest', 'get', 'go', 'had', 
    'halves', 'hardly', 'has', 'hast', 'hath', 'have', 'he', 'hence', 
    'henceforth', 'her', 'here', 'hereabouts', 'hereafter', 'hereby', 'herein', 
    'hereto', 'hereupon', 'hers', 'herself', 'him', 'himself', 'hindmost', 'his', 
    'hither', 'hitherto', 'how','however', 'howsoever', 'i', 'ie', 'if', 'in', 
    'inasmuch', 'inc', 'include', 'included', 'including', 'indeed', 'indoors', 
    'inside', 'insomuch', 'instead', 'into', 'inward', 'inwards', 'is', 'it', 
    'its', 'itself', 'just', 'kg', 'kind', 'km', 'last', 'latter', 'latterly', 
    'less', 'lest', 'let', 'like', 'little', 'ltd', 'many', 'may', 'maybe', 'me', 
    'meantime', 'meanwhile', 'might', 'more','moreover', 'most', 'mostly', 'mr', 
    'mrs', 'ms', 'much', 'must', 'my', 'myself', 'namely', 'need', 'neither', 
    'never', 'nevertheless', 'next', 'no', 'nobody', 'none', 'nonetheless', 
    'noone', 'nope', 'nor', 'not', 'nothing', 'notwithstanding', 'now', 
    'nowadays', 'nowhere', 'of', 'off', 'often', 'ok', 'on', 'once', 'one', 
    'only', 'onto', 'or', 'other', 'others', 'otherwise', 'ought', 'our', 
    'ours', 'ourselves', 'out', 'outside', 'over', 'own', 'per', 'perhaps', 
    'plenty', 'provide', 'quite', 'rather', 'really', 'round', 'said', 'sake', 
    'same', 'sang', 'save', 'saw', 'see', 'seeing', 'seem', 'seemed', 'seeming', 
    'seems', 'seen', 'seldom', 'selves', 'sent', 'several', 'shalt', 'she', 
    'should', 'shown', 'sideways', 'since', 'slept', 'slew', 'slung', 'slunk', 
    'smote', 'so', 'some', 'somebody', 'somehow', 'someone', 'something', 
    'sometime', 'sometimes', 'somewhat', 'somewhere', 'spake', 'spat', 'spoke', 
    'spoken', 'sprang', 'sprung', 'stave', 'staves', 'still', 'such', 'supposing', 
    'than', 'that', 'the', 'thee', 'their', 'them', 'themselves', 'then', 'thence', 
    'thenceforth', 'there', 'thereabout', 'thereabouts', 'thereafter', 'thereby', 
    'therefore', 'therein', 'thereof', 'thereon', 'thereto', 'thereupon', 'these', 
    'they', 'this', 'those', 'thou', 'though', 'thrice', 'through', 'throughout', 
    'thru', 'thus', 'thy', 'thyself', 'till', 'to', 'together', 'too', 'toward', 
    'towards', 'ugh', 'unable', 'under', 'underneath', 'unless', 'unlike', 'until', 
    'up', 'upon', 'upward', 'upwards', 'us', 'use', 'used', 'using', 'very', 'via', 
    'vs', 'want', 'was', 'we', 'week', 'well', 'were', 'what', 'whatever', 
    'whatsoever', 'when', 'whence', 'whenever', 'whensoever', 'where', 'whereabouts', 
    'whereafter', 'whereas', 'whereat', 'whereby', 'wherefore', 'wherefrom', 
    'wherein', 'whereinto', 'whereof', 'whereon', 'wheresoever', 'whereto', 'whereunto', 
    'whereupon', 'wherever', 'wherewith', 'whether', 'whew', 'which', 'whichever', 
    'whichsoever', 'while', 'whilst', 'whither', 'who', 'whoa', 'whoever', 'whole', 
    'whom', 'whomever', 'whomsoever', 'whose', 'whosoever', 'why', 'will', 'wilt', 
    'with', 'within', 'without', 'worse', 'worst', 'would', 'wow', 'ye', 'year', 'yet', 
    'yippee', 'you', 'your', 'yours', 'yourself', 'yourselves'
}

nlp = spacy.load('en_core_sci_sm') 

original_query_file = "topics-rnd5.xml"

# %%
from lxml import etree

# %%
root = etree.parse(original_query_file).getroot()

# %%
for topic in root:
    qid = topic.attrib['number']
    for q in topic:
        if q.tag == 'query':
            query = q.text.strip()
            new = [w.text for w in nlp(query) if w.text not in stopwords]
        elif q.tag == 'question':
            question = q.text.strip()
            new += [w.text for w in nlp(question).ents]

    tags_to_be_removed = []
    for q in topic:
        if q.tag == 'query':
            q.text = ' '.join(new)
        else:
            tags_to_be_removed.append(q)

    for tag in tags_to_be_removed:
        topic.remove(tag)

# %%
for topic in root:
    qid = topic.attrib['number']
    for q in topic:
        print(q.text)
# Out:
# coronavirus origin origin COVID-19
# coronavirus response weather changes coronavirus changes weather
# coronavirus immunity SARS-CoV2 infected people immunity cross protection
# people die coronavirus death Covid-19
# animal models COVID-19 drugs SARS-CoV SARS-CoV-2 animal studies
# coronavirus test rapid testing rapid testing Covid-19
# serological tests coronavirus serological tests detect antibodies coronavirus
# coronavirus reporting lack testing availability underreporting true incidence Covid-19
# coronavirus Canada COVID-19 affected Canada
# coronavirus social distancing impact social distancing impact slowing spread COVID-19
# coronavirus hospital rationing guidelines triaging patients infected coronavirus
# coronavirus quarantine practices hospitals home quarantine
# coronavirus spread transmission coronavirus
# coronavirus super spreaders evidence COVID-19 super spreaders
# coronavirus body long coronavirus live body
# long coronavirus survive surfaces long does coronavirus stable surfaces
# coronavirus clinical trials clinical trials coronavirus
# masks prevent coronavirus infection Covid-19
# alcohol sanitizer kills coronavirus type hand sanitizer destroy Covid-19
# coronavirus ACE inhibitors patients Angiotensin-converting enzyme inhibitors ACE increased risk COVID-19
# coronavirus mortality mortality rates populations
# coronavirus heart impacts cardiac complications patients COVID-19
# coronavirus hypertension kinds complications COVID-19 associated with hypertension
# coronavirus diabetes kinds complications COVID-19 associated with diabetes
# coronavirus biomarkers biomarkers severe clinical course infection
# coronavirus early symptoms symptoms Covid-19
# coronavirus asymptomatic infected Covid-19 asymptomatic
# coronavirus hydroxychloroquine evidence hydroxychloroquine treating Covid-19
# coronavirus drug repurposing SARS-CoV-2 proteins-human proteins interactions drug targets drugs repurposed information
# coronavirus remdesivir effective treatment COVID-19
# difference coronavirus flu coronavirus seasonal flu
# coronavirus subtypes SARS-CoV-2 subtypes
# coronavirus vaccine candidates vaccine Covid-19
# coronavirus recovery longer-term complications recover COVID-19
# coronavirus public datasets public datasets COVID-19
# SARS-CoV-2 spike structure protein structure SARS-CoV-2 spike
# SARS-CoV-2 phylogenetic analysis phylogenetic analysis SARS-CoV-2 genome sequence
# COVID inflammatory response mechanism inflammatory response pathogenesis COVID-19 cases
# COVID-19 cytokine storm mechanism cytokine storm syndrome COVID-19
# coronavirus mutations mutations SARS-CoV-2 genome mutations
# COVID-19 African-Americans impacts COVID-19 African-Americans U.S. population
# Vitamin D COVID-19 Vitamin D impact COVID-19 prevention treatment
# violence pandemic COVID-19 society violent crimes
# impact masks coronavirus transmission impact spread COVID-19
# coronavirus mental health impact COVID-19
# dexamethasone coronavirus evidence dexamethasone treatment COVID-19
# COVID-19 outcomes children health outcomes children contract COVID-19
# school reopening coronavirus benefits risks schools midst COVID-19 pandemic
# post-infection COVID-19 immunity individuals recover COVID-19 immune response antibody levels T-cell immunity re-infection
# mRNA vaccine coronavirus mRNA vaccine SARS-CoV-2 virus

# %%
from pyserini.search import pysearch

searcher = pysearch.SimpleSearcher(COVID_INDEX)
query = ('these differences reside in the molecular structure of spike proteins and some other factors. Which receptor combination(s) will cause maximum harm')
hits = show_query_results(query, searcher, top_k=10)
